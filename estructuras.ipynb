# %%
url="https://blog.boot.dev/computer-science/binary-search-tree-in-python/"

# %% [markdown]
# 1) Diseñar una clase que permita trabajar con un árbol binario y que contenga los métodos:<br>
#     * insertaVal: para insertar un dato<br>
#     * buscaVal: que devuelva True o False si existe o no un dato<br>
#     * verVal: que imprima por pantalla los valores del árbol<br>
#
# Nota: Se puede utilizar la recursividad

# %%
class BSTNode:
    def __init__(self, val=None):
        self.left = None
        self.right = None
        self.val = val
    
    #Si no existe la raiz inserta el valor ahi
    def insert(self, val):
        if not self.val:
            self.val = val
            return

        #Si es el mismo valor ignora
        if self.val == val:
            return

        #Si es menor a la raiz comprueba si es null el brazo izq
        #Si es null crea un nodo con value 
        #Si no es null recursa la funcion insert en el nodo existente
        if val < self.val:
            if self.left:
                self.left.insert(val)
                return
            self.left = BSTNode(val)
            return

        if self.right:
            self.right.insert(val)
            return
        self.right = BSTNode(val)

    #Recursa el lado izquierdo hasta None el nodo anterior a None es el minimo
    def get_min(self):
        current = self
        while current.left is not None:
            current = current.left
        return current.val

    #Recursa el lado derecho hasta None el nodo anterior a None es el maximo
    def get_max(self):
        current = self
        while current.right is not None:
            current = current.right
        return current.val


    #Si el valor enviado es la raiz devuelve True
    def exists(self, val):
        if val == self.val:
            return True

        #Si el valor enviado es menor a la raiz y no existe izquierda devuelve False
        #Si izquierda existe recursa la funcion exists() con el valor del nodo izquierdo
        if val < self.val:
            if self.left == None:
                return False
            return self.left.exists(val)
        
        #Si el valor enviado es mayor a la raiz y no existe derecha devuelve False
        #Si derecha existe recursa la funcion exists() con el valor del nodo derecho
        if self.right == None:
            return False
        return self.right.exists(val)

    #raiz,hojas izquierdas descendente, hojas derechas descendente
    def preorder(self, vals):
        if self.val is not None:
            vals.append(self.val)
        if self.left is not None:
            self.left.preorder(vals)
        if self.right is not None:
            self.right.preorder(vals)
        return vals
    
    #De menor a mayor
    def inorder(self, vals):
        if self.left is not None:
            self.left.inorder(vals)
        if self.val is not None:
            vals.append(self.val)
        if self.right is not None:
            self.right.inorder(vals)
        return vals

        #hojas izquierdas ascendente,hojas derechas ascendente,raiz
    def postorder(self, vals):
        if self.left is not None:
            self.left.postorder(vals)
        if self.right is not None:
            self.right.postorder(vals)
        if self.val is not None:
            vals.append(self.val)
        return vals

# %%
#De menor a mayor
a=BSTNode()
a.insert(5)
a.insert(2)
a.insert(7)
a.insert(9)
a.insert(8)
a.insert(1)
a.inorder([])
# Out:
# [1, 2, 5, 7, 8, 9]

# %%
#hojas izquierdas ascendente,hojas derechas ascendente,raiz
a=BSTNode()
a.insert(5)
a.insert(2)
a.insert(7)
a.insert(9)
a.insert(8)
a.insert(1)
a.postorder([])
# Out:
# [1, 2, 8, 9, 7, 5]

# %%
#raiz,hojas izquierdas descendente, hojas derechas descendente
a=BSTNode()
a.insert(5)
a.insert(2)
a.insert(7)
a.insert(9)
a.insert(8)
a.insert(1)

a.preorder([])
# Out:
# [5, 2, 1, 7, 9, 8]

# %% [markdown]
# ![](https://raw.githubusercontent.com/joacota2/BinaryTree/main/arbol.png)

# %%
class BSTNode:
    def __init__(self, val=None):
        self.left = None
        self.right = None
        self.val = val
    
    #Si no existe la raiz inserta el valor ahi
    def insert(self, val):
        if not self.val:
            self.val = val
            return

        #Si es el mismo valor ignora
        if self.val == val:
            return

        #Si es menor a la raiz comprueba si es null el brazo izq
        #Si es null crea un nodo con value 
        #Si no es null recursa la funcion insert en el nodo existente
        if val < self.val:
            if self.left:
                self.left.insert(val)
                return
            self.left = BSTNode(val)
            return

        if self.right:
            self.right.insert(val)
            return
        self.right = BSTNode(val)

    #Recursa el lado izquierdo hasta None el nodo anterior a None es el minimo
    def get_min(self):
        current = self
        while current.left is not None:
            current = current.left
        return current.val

    #Recursa el lado derecho hasta None el nodo anterior a None es el maximo
    def get_max(self):
        current = self
        while current.right is not None:
            current = current.right
        return current.val

    #Hace un quilombo barbaro elimina el valor enviado y devuelve el nuevo estado del nodo.
    def delete(self, val):
        #Si no existe raiz termina la ejecucion.
        if self == None:
            return self
        #Si es menor a raiz y no es None recursa delete() con el nodo izquierdo.
        if val < self.val:
            if self.left:
                self.left = self.left.delete(val)
            return self
        #Si es mayor a raiz y no es None recursa delete() con el nodo derecho.
        if val > self.val:
            if self.right:
                self.right = self.right.delete(val)
            return self
        #Si no existe derecha termina la ejecucion.
        if self.right == None:
            return self.left

        #Si no existe izquierda termina la ejecucion.
        if self.left == None:
            return self.right
        #Crea nueva variable con valor de nodo derecho
        min_larger_node = self.right

        #
        while min_larger_node.left:
            min_larger_node = min_larger_node.left
        self.val = min_larger_node.val
        self.right = self.right.delete(min_larger_node.val)
        return self

    #Si el valor enviado es la raiz devuelve True
    def exists(self, val):
        if val == self.val:
            return True

        #Si el valor enviado es menor a la raiz y no existe izquierda devuelve False
        #Si izquierda existe recursa la funcion exists() con el valor del nodo izquierdo
        if val < self.val:
            if self.left == None:
                return False
            return self.left.exists(val)
        
        #Si el valor enviado es mayor a la raiz y no existe derecha devuelve False
        #Si derecha existe recursa la funcion exists() con el valor del nodo derecho
        if self.right == None:
            return False
        return self.right.exists(val)

    #raiz,hojas izquierdas descendente, hojas derechas descendente
    def preorder(self, vals):
        if self.val is not None:
            vals.append(self.val)
        if self.left is not None:
            self.left.preorder(vals)
        if self.right is not None:
            self.right.preorder(vals)
        return vals
    
    #De menor a mayor
    def inorder(self, vals):
        if self.left is not None:
            self.left.inorder(vals)
        if self.val is not None:
            vals.append(self.val)
        if self.right is not None:
            self.right.inorder(vals)
        return vals

        #hojas izquierdas ascendente,hojas derechas ascendente,raiz
    def postorder(self, vals):
        if self.left is not None:
            self.left.postorder(vals)
        if self.right is not None:
            self.right.postorder(vals)
        if self.val is not None:
            vals.append(self.val)
        return vals
